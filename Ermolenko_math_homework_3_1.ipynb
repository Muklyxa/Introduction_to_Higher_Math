# %% [markdown]
# # Задания к уроку 2

# %% [markdown]
# ### 1. Задание

# %% [markdown]
# Даны два вектора в трехмерном пространстве: (10,10,10) и (0,0,-10)
#
# 2) Напишите код на Python, реализующий расчет длины вектора, заданного его
# координатами. (в программе)

# %%
import math

# %%
x1 = [10, 10, 10]
x2 = [0, 0, -10]

# %%
def vector_len(x):
    sum = 0
    for i in range(len(x)):
        sum += x[i]*x[i]
    return math.sqrt(sum)

# %%
print(f"Length of x1 is: {vector_len(x1)}")
print(f"Length of x2 is: {vector_len(x2)}")
# Out:
# Length of x1 is: 17.320508075688775
# Length of x2 is: 10.0

# %% [markdown]
# ### 3. Задание (в программе)

# %% [markdown]
# Напишите код на Python, реализующий построение графиков:
# 1. окружности,
# 2. эллипса,
# 3. гиперболы.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
x0 = 3
y0 = -4
R = 5

x = np.linspace(-10, 10, 1001)

# %%
y = np.sqrt(R*R - (x - x0)**2)
y1 = -y

y = y + y0
y1 = y1 + y0

plt.figure(figsize=(8, 8))
plt.xlim(-10, 10)
plt.ylim(-10, 10)
plt.grid(True)
plt.plot(x, y, x, y1)
# Out:
# <ipython-input-7-bf21b4e358e0>:1: RuntimeWarning: invalid value encountered in sqrt
#   y = np.sqrt(R*R - (x - x0)**2)
# [<matplotlib.lines.Line2D at 0x1cbf489a670>,
#  <matplotlib.lines.Line2D at 0x1cbf489a6a0>]

# %%
x0 = -3
y0 = 4
a = 5
b=3

x = np.linspace(-10, 10, 1001)

# %%
y = (b/a)*np.sqrt(a*a - (x - x0)**2)
y1 = -y

y = y + y0
y1 = y1 + y0

plt.figure(figsize=(8, 8))
plt.xlim(-10, 10)
plt.ylim(-10, 10)
plt.grid(True)
plt.plot(x, y, x, y1)
# Out:
# <ipython-input-9-1a98e34737c4>:1: RuntimeWarning: invalid value encountered in sqrt
#   y = (b/a)*np.sqrt(a*a - (x - x0)**2)
# [<matplotlib.lines.Line2D at 0x1cbf4a985e0>,
#  <matplotlib.lines.Line2D at 0x1cbf4a986d0>]

# %%
x0 = -1
y0 = 1
a = 0.5
b=0.4

x = np.linspace(-10, 10, 1001)

# %%
y = (b/a)*np.sqrt((x - x0)**2 - a*a)
y1 = -y

y = y + y0
y1 = y1 + y0

plt.figure(figsize=(8, 8))
plt.xlim(-10, 10)
plt.ylim(-10, 10)
plt.grid(True)
plt.plot(x, y, x, y1)
# Out:
# <ipython-input-11-5986c926c357>:1: RuntimeWarning: invalid value encountered in sqrt
#   y = (b/a)*np.sqrt((x - x0)**2 - a*a)
# [<matplotlib.lines.Line2D at 0x1cbf49743d0>,
#  <matplotlib.lines.Line2D at 0x1cbf49744c0>]

# %% [markdown]
# ### 5. Задание (в программе)

# %% [markdown]
# 1) Нарисуйте трехмерный график двух параллельных плоскостей.
#
# 2) Нарисуйте трехмерный график двух любых поверхностей второго порядка.

# %%
from pylab import *
from mpl_toolkits.mplot3d import Axes3D
fig = figure()
ax = Axes3D(fig)
X = np.arange(-20, 20, 1)
Y = np.arange(-20, 20, 1)
X, Y = np.meshgrid(X, Y)
A = 3
B = 7
C = 4
D = -20
Z = -(A/C)*X - (B/C)*Y - D/C
ax.plot_surface(X, Y, Z)

E=1/3
A = A*E
B = B*E
C = C*E
D = 0
Z = -(A/C)*X - (B/C)*Y - D/C
ax.plot_surface(X, Y, Z)
show()

# %%
fig = figure()
ax = Axes3D(fig)
X = np.arange(-10, 10, 1)
Y = np.arange(-10, 10, 1)
X, Y = np.meshgrid(X, Y)
a = 3
b = -7
Z = ((X*X)/(a*a)) - ((Y*Y)/(b*b))
ax.plot_wireframe(X, Y, Z)
show()

# %%
fig = figure()
ax = Axes3D(fig)
X = np.arange(-1, 1, 0.1)
Y = np.arange(-1, 1, 0.1)
X, Y = np.meshgrid(X, Y)
a = 1
b = 1
c = 1
Z = c*np.sqrt(1 - ((X*X)/(a*a)) - ((Y*Y)/(b*b)))
Z1 = -Z
ax.plot_wireframe(X, Y, Z)
ax.plot_wireframe(X, Y, Z1)
show()
# Out:
# <ipython-input-14-ac273c1fd728>:9: RuntimeWarning: invalid value encountered in sqrt
#   Z = c*np.sqrt(1 - ((X*X)/(a*a)) - ((Y*Y)/(b*b)))

# %% [markdown]
# # Задания к уроку 3

# %% [markdown]
# ### 1. Задание (в программе)

# %% [markdown]
# Нарисуйте график функции:
# y(x) = k·cos(x – a) + b
# для некоторых (2-3 различных) значений параметров k, a, b

# %%
x = np.linspace(-2*np.pi, 3*np.pi, 201)
y1 = np.sin(x)
y2 = 2*np.cos(x + np.pi/2) + 1
y3 = -1.5*np.cos(x - np.pi/2) + 3
plt.plot(x, y1)
plt.plot(x, y2)
plt.plot(x, y3)
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)
plt.show()

# %% [markdown]
# ### 3. Задание (в программе)

# %% [markdown]
# 1. Напишите код, который будет переводить полярные координаты в декартовы.

# %%
def transform(R, a):
    return R*np.cos(a), R*np.sin(a)

# %%
x, y = transform(1, 0*np.pi/180)
print(x, y)
x, y = transform(1, 45*np.pi/180)
print(x, y)
x, y = transform(1, 90*np.pi/180)
print(x, y)
x, y = transform(1, 180*np.pi/180)
print(x, y)
x, y = transform(1, 270*np.pi/180)
print(x, y)
# Out:
# 1.0 0.0
# 0.7071067811865476 0.7071067811865476
# 6.123233995736766e-17 1.0
# -1.0 1.2246467991473532e-16
# -1.8369701987210297e-16 -1.0

# %% [markdown]
# 2. Напишите код, который будет рисовать график окружности в полярных
# координатах.

# %%
x0 = 1
y0 = -1
R = 2

x = np.linspace(-10, 10, 1001)

# %%
y = np.sqrt(R*R - (x - x0)**2)
y1 = -y

y = y + y0
y1 = y1 + y0

plt.polar(x, y, x, y1)
# Out:
# <ipython-input-65-05cf00e6b0a3>:1: RuntimeWarning: invalid value encountered in sqrt
#   y = np.sqrt(R*R - (x - x0)**2)
# [<matplotlib.lines.Line2D at 0x1cbf5fd49a0>,
#  <matplotlib.lines.Line2D at 0x1cbf5fd4a00>]
# C:\Users\Muklyxa\anaconda3\lib\site-packages\matplotlib\projections\polar.py:55: RuntimeWarning: invalid value encountered in greater_equal
#   r = np.where(r >= 0, r, np.nan)

# %% [markdown]
# 3. Напишите код, который будет рисовать график отрезка прямой линии в
# полярных координатах.

# %%
k = 1
b = 0

x = np.linspace(-10, 10, 1001)

# %%
y = k*x + b

plt.polar(x, y)

# %% [markdown]
# ### 4. Задание (в программе)

# %% [markdown]
# 1) Решите систему уравнений:
#
# y = x 2 – 1
#
# exp(x) + x·(1 – y) = 1

# %%
from scipy.optimize import fsolve

x = np.linspace(-2, 5, 1001)
plt.plot(x, x*x - 1)
plt.plot(x, (np.exp(x) + x - 1)/x)
plt.xlabel('x')
plt.ylabel('y')
plt.ylim(-1, 20) 
plt.grid(True)
plt.show()

def equations(p):
    x, y = p
    return (y - x**2 + 1, np.exp(x) + x*(1 - y) - 1)

x1, y1 =  fsolve(equations, (-2, 0))          
print (x1, y1)
x2, y2 =  fsolve(equations, (2, 5))          
print (x2, y2)
x3, y3 =  fsolve(equations, (4, 15))          
print (x3, y3)
# Out:
# -1.581835352895898 1.5022030836712148
# 2.6181455730830665 5.854686241850253
# 4.200105841149689 16.640889076862805

# %% [markdown]
# 2) Решите систему уравнений и неравенств:
#
# y = x 2 – 1
#
# exp(x) + x·(1 – y) > 1

# %%
x = np.linspace(-2, 5, 1001)
plt.plot(x, x*x - 1)
plt.plot(x, (np.exp(x) + x - 1)/x)
plt.xlabel('x')
plt.ylabel('y')
plt.ylim(-1, 20) 
plt.grid(True)
plt.show()

def equations(p):
    x, y = p
    return (y - x**2 + 1, np.exp(x) + x*(1 - y) - 1)

x1, y1 =  fsolve(equations, (-2, 0))          
print (x1, y1)
x2, y2 =  fsolve(equations, (2, 5))          
print (x2, y2)
x3, y3 =  fsolve(equations, (4, 15))          
print (x3, y3)
