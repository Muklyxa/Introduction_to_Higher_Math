# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
k1 = 1
k2 = 3

x = np.linspace(0, 2*np.pi, 100)
y1 = np.cos(k1*x)
y2 = np.cos(k2*x)

# %%
plt.plot(x, y1, x, y2)
plt.xlabel('x')
plt.ylabel('y')
plt.show()
